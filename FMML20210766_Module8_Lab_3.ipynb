# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayasreenivas0305/fmml/blob/main/FMML20210766_Module8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-18 06:30:08--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   179MB/s    in 0.4s
#
# 2022-06-18 06:30:12 (179 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11035   1311.5750v2  Hard Thresholding Pursuit (HTP) is an iterativ...    cs
# 22725  1705.07178v2  Inference of latent feature models in the Baye...  stat
# 22210  1508.00085v1  Log-density gradient estimation is a fundament...  stat
# 6444   1702.01992v1  This paper presents a novel model for multimod...  stat
# 29775  1710.05267v2  PURPOSE: Demonstrate a novel fast method for r...    cs
# ...             ...                                                ...   ...
# 6351   1611.06080v1  While much research effort has been dedicated ...  stat
# 27313  1703.02271v1  The study on point sources in astronomical ima...    cs
# 21677   0909.1440v1  We present an extension of sparse PCA, or spar...  stat
# 20331  1509.08434v1  Recent results have shown that the MCTS algori...    cs
# 7461   1801.01799v1  We present novel understandings of the Gamma-P...  stat
#
#                                                    title  year  \
# 11035  Gradient Hard Thresholding Pursuit for Sparsit...  2013
# 22725   Accelerated Inference for Latent Variable Models  2017
# 22210  Regularized Multi-Task Learning for Multi-Dime...  2015
# 6444       Gated Multimodal Units for Information Fusion  2017
# 29775  Deep Learning for Rapid Sparse MR Fingerprinti...  2017
# ...                                                  ...   ...
# 6351   A Generalized Stochastic Variational Bayesian ...  2016
# 27313  X-ray Astronomical Point Sources Recognition U...  2017
# 21677     Structured Sparse Principal Component Analysis  2009
# 20331               Ensemble UCT Needs High Exploitation  2015
# 7461   Closed-form marginal likelihood in Gamma-Poiss...  2018
#
#                                                 keywords
# 11035  [thresholding, iterative, selection, procedure...
# 22725  [inference, nonparametric, generally, difficul...
# 22210  [estimation, fundamental, statistical, possess...
# 6444   [multimodal, multimodal, architecture, interme...
# 29775  [demonstrate, reconstruction, dimensional, fin...
# ...                                                  ...
# 6351   [dedicated, variables, attention, approximatio...
# 27313  [astronomical, importance, energetic, celestia...
# 21677  [extension, dictionary, dictionary, structured...
# 20331  [algorithm, randomized, optimization, effectiv...
# 7461   [understandings, probabilistic, factorization,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11035    [thresholding, iterative, selection, procedure...
# 22725    [inference, nonparametric, generally, difficul...
# 22210    [estimation, fundamental, statistical, possess...
# 6444     [multimodal, multimodal, architecture, interme...
# 29775    [demonstrate, reconstruction, dimensional, fin...
#                                ...
# 23071    [simulation, multidimensional, processes, supe...
# 86       [representing, relations, important, applicati...
# 22176    [technique, clustering, categorical, generatin...
# 10849    [regression, parametric, regression, applicati...
# 37178    [recommendation, customers, recommendation, re...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8839 words.
# Out of those 4616 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a6c2eca3-8432-4b33-89f8-4f51e74d074a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6c2eca3-8432-4b33-89f8-4f51e74d074a")) {                    Plotly.newPlot(                        "a6c2eca3-8432-4b33-89f8-4f51e74d074a",                        [{"x":["compressive","parameter","debiasing","regression","precision","impressive","evidences","procedure","guarantees","numerical","iterative","theoretical","optimization","generalize","selection","guarantee","constrained","analogous","performance","convergence","thresholding","algorithm","solutions","underdetermined","estimation","according","assignments","efficient","accelerated","tractable","proposing","computationally","dimensions","integration","posterior","locations","difficult","inference","theoretically","nonparametric","attractive","accelerate","guaranteed","predictive","dimensional","generally","performed","especially","distribution","likelihood","usefulness","measuring","experimentally","gaussianity","unreliable","possesses","statistical","fundamental","estimator","practical","demonstrated","regularized","clustering","necessarily","objective","applications","estimating","demonstrate","dimension","influence","including","knowledge","strategies","different","prediction","multimodal","outperformed","information","approaches","combination","available","multilabel","architecture","modalities","representation","activation","intermediate","classification","evaluated","multiplicative","fingerprinting","framework","approximately","conventional","reference","conclusion","undersampling","reconstruction","quantified","agreement","simulated","equations","dictionary","estimated","dictionaries","measurements","tensorflow","synthesis","classifier","conditional","synthesizing","adversarial","conditioning","photorealistic","assessing","exhibiting","challenge","resolution","coherence","generative","auxiliary","assessment","diversity","construct","discriminability","employing","comparable","artificially","introduce","resources","considered","candidate","independent","environment","limitation","important","promising","benchmark","represent","congestion","decentralized","applicability","allocation","difference","satisfied","analysing","assumptions","literature","abstraction","omnipresent","behaviour","application","highlight","reinforcement","imitation","experimental","estimators","distillation","predictions","overfitting","transfers","baselines","parameters","optimized","effective","emergencies","algorithms","disasters","smartphones","excellent","everywhere","awareness","situations","researchers","situation","techniques","understanding","challenges","therefore","situational","decisions","consequently","installed","emergency","quadratic","approximation","multiplication","bernsteins","inequality","randomized","distributed","experiments","technique","architectures","probability","coordinate","clickstream","regularization","addresses","empirically"],"y":[16,130,2,101,77,22,6,127,64,85,72,160,345,59,163,36,51,10,893,126,21,843,139,3,182,89,15,415,22,32,26,103,40,45,46,33,139,223,31,19,24,20,37,57,206,66,113,127,234,70,28,27,50,0,13,8,166,96,27,135,102,33,130,19,163,437,60,571,72,75,258,344,98,766,235,35,16,725,396,146,279,7,253,39,346,32,29,478,134,13,1,565,40,87,53,18,2,93,18,18,60,27,55,53,25,77,7,44,138,110,9,93,14,4,12,14,148,111,13,125,25,37,50,89,1,28,111,9,329,61,126,49,138,135,16,359,105,215,112,3,13,31,16,62,15,9,64,114,23,1,36,254,37,114,6,363,12,7,83,29,1,61,251,46,254,3,588,2,6,26,5,9,52,73,33,379,159,111,173,6,52,31,6,3,19,110,12,1,12,31,114,628,248,97,170,23,0,83,54,73],"type":"bar"},{"x":["compressive","parameter","debiasing","regression","precision","impressive","evidences","procedure","gu ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4616,), (4616, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8083333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.4222222222222223);'>Programming</span> <span style=''>Patterns</span> <span style=''>in</span> <span style=''>Dataflow</span> <span style=''>Matrix</span> <span style=''>Machines</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generalized</span> <span style='background-color:rgba(0, 255, 0, 0.393939393939394);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Nets</span> <br/><br/><span style=''>Dataflow</span> <span style=''>matrix</span> <span style=''>machines</span> <span style=''>arise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synchronous</span> <span style=''>dataflow</span> <span style='background-color:rgba(0, 255, 0, 0.4222222222222223);'>programming</span> <span style=''>with</span> <span style=''>linear</span> <span style=''>streams</span> <span style=''>They</span> <span style=''>can</span> <span style=''>be</span> <span style=''>viewed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>rather</span> <span style=''>powerful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.393939393939394);'>recurrent</span> <span style=''>neural</span> <span style=''>networks</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Similarly</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.393939393939394);'>recurrent</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>large</span> <span style=''>classes</span> <span style=''>of</span> <span style=''>dataflow</span> <span style=''>matrix</span> <span style=''>machines</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>described</span> <span style=''>by</span> <span style=''>matrices</span> <span style=''>of</span> <span style=''>numbers</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>therefore</span> <span style=''>dataflow</span> <span style=''>matrix</span> <span style=''>machines</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>synthesized</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>their</span> <span style=''>matrices</span> <span style=''>At</span> <span style=''>the</span> <span style=''>same</span> <span style=''>time</span> <span style=''>the</span> <span style=''>evidence</span> <span style=''>is</span> <span style=''>fairly</span> <span style=''>strong</span> <span style=''>that</span> <span style=''>dataflow</span> <span style=''>matrix</span> <span style=''>machines</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressive</span> <span style=''>power</span> <span style=''>to</span> <span style=''>be</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>convenient</span> <span style=''>general</span> <span style=''>purpose</span> <span style='background-color:rgba(0, 255, 0, 0.4222222222222223);'>programming</span> <span style=''>platform</span> <span style=''>Because</span> <span style=''>of</span> <span style=''>the</span> <span style=''>network</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>this</span> <span style=''>platform</span> <span style='background-color:rgba(0, 255, 0, 0.4222222222222223);'>programming</span> <span style=''>patterns</span> <span style=''>often</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correspond</span> <span style=''>to</span> <span style=''>patterns</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Class</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Splitting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Networks</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Networks</span> <span style=''>(GANs)</span> <span style=''>produce</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>systematically</span> <span style=''>better</span> <span style=''>quality</span> <span style=''>samples</span> <span style=''>when</span> <span style=''>class</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>is</span> <span style=''>provided</span> <span style=''>ie</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>GAN</span> <span style=''>setup</span> <span style=''>This</span> <span style=''>is</span> <span style=''>still</span> <span style=''>observed</span> <span style=''>for</span> <span style=''>the</span> <span style=''>recently</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Wasserstein</span> <span style=''>GAN</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stabilized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>training</span> <span style=''>and</span> <span style=''>allows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considering</span> <span style=''>high</span> <span style=''>capacity</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>such</span> <span style=''>as</span> <span style=''>ResNet</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>to</span> <span style=''>boost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>GAN</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>augmenting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>class</span> <span style=''>labels</span> <span style=''>The</span> <span style=''>new</span> <span style=''>classes</span> <span style=''>come</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>space</span> <span style=''>learned</span> <span style=''>by</span> <span style=''>the</span> <span style=''>same</span> <span style=''>GAN</span> <span style=''>model</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>strategy</span> <span style=''>is</span> <span style=''>also</span> <span style=''>feasible</span> <span style=''>when</span> <span style=''>no</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>ie</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>setup</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>samples</span> <span style=''>reach</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgb ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Exact</span> <span style=''>Hybrid</span> <span style='background-color:rgba(255, 0, 0, 0.6964285714285715);'>Covariance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Thresholding</span> <span style=''>for</span> <span style=''>Joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Graphical</span> <span style=''>Lasso</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considers</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4059405940594059);'>estimating</span> <span style=''>multiple</span> <span style=''>related</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>from</span> <span style=''>a</span> <span style=''>p</span> <span style='background-color:rgba(255, 0, 0, 0.30050933786078093);'>dimensional</span> <span style=''>dataset</span> <span style='background-color:rgba(0, 255, 0, 0.31578947368421056);'>consisting</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3321739130434782);'>different</span> <span style=''>classes</span> <span style=''>Our</span> <span style=''>work</span> <span style=''>is</span> <span style=''>based</span> <span style=''>upon</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>as</span> <span style=''>group</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>lasso</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>hybrid</span> <span style='background-color:rgba(255, 0, 0, 0.6964285714285715);'>covariance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>thresholding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3454545454545454);'>effectively</span> <span style=''>identify</span> <span style=''>zero</span> <span style=''>entries</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precision</span> <span style=''>matrices</span> <span style=''>and</span> <span style=''>split</span> <span style=''>a</span> <span style=''>large</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>lasso</span> <span style=''>problem</span> <span style=''>into</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subproblems</span> <span style=''>Our</span> <span style=''>hybrid</span> <span style='background-color:rgba(255, 0, 0, 0.6964285714285715);'>covariance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>thresholding</span> <span style=''>method</span> <span style=''>is</span> <span style=''>superior</span> <span style=''>to</span> <span style=''>existing</span> <span style=''>uniform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>thresholding</span> <span style=''>methods</span> <span style=''>in</span> <span style=''>that</span> <span style=''>our</span> <span style=''>method</span> <span style=''>can</span> <span style=''>split</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precision</span> <span style=''>matrix</span> <span style=''>of</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individual</span> <span style=''>class</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3321739130434782);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>for</span> <span style=''>Large</span> <span style=''>Scale</span> <span style=''>Max</span> <span style=''>Norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regularization</span> <br/><br/><span style=''>Max</span> <span style=''>norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularizer</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensively</span> <span style=''>studied</span> <span style=''>in</span> <span style=''>the</span> <span style=''>last</span> <span style=''>decade</span> <span style=''>as</span> <span style=''>it</span> <span style=''>promotes</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>data</span> <span style=''>However</span> <span style=''>such</span> <span style=''>max</span> <span style=''>norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style=''>problems</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulated</span> <span style=''>and</span> <span style=''>solved</span> <span style=''>in</span> <span style=''>a</span> <span style=''>batch</span> <span style=''>manner</span> <span style=''>which</span> <span style=''>prevents</span> <span style=''>it</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>big</span> <span style=''>data</span> <span style=''>due</span> <span style=''>to</span> <span style=''>possible</span> <span style=''>memory</span> <span style=''>budget</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>hence</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>is</span> <span style=''>scalable</span> <span style=''>to</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>setting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Particularly</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>problem</span> <span style=''>as</span> <span style=''>an</span> <span style=''>example</span> <span style=''>although</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>analysis</span> <span style=''>can</span> <span style=''>be</span> <span style=''>adapted</span> <span style=''>to</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>problems</span> <span style=''>such</span> <span style=''>as</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completion</span> <span style=''>The</span> <span style=''>crucial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>in</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reformulating</span> <span style=''>the</s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.04991150442477876)
# 	representation (0.12247787610619469)
# 	knowledge (0.12176991150442477)
# 	processing (0.10761061946902654)
# 	architecture (0.0895575221238938)
# 	information (0.25663716814159293)
# 	detection (0.12070796460176991)
# 	different (0.2711504424778761)
# 	recognition (0.12530973451327435)
# 	convolutional (0.13132743362831859)
#
# Some Statistics words are:
# 	algorithm (0.38734177215189874)
# 	theoretical (0.14734177215189873)
# 	stochastic (0.13721518987341771)
# 	statistical (0.15949367088607594)
# 	variables (0.1508860759493671)
# 	estimation (0.1827848101265823)
# 	distribution (0.20253164556962025)
# 	dimensional (0.1939240506329114)
# 	inference (0.20658227848101265)
# 	regression (0.1858227848101266)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="36b83f26-42a0-427c-bbe2-db4d1b435e8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36b83f26-42a0-427c-bbe2-db4d1b435e8b")) {                    Plotly.newPlot(                        "36b83f26-42a0-427c-bbe2-db4d1b435e8b",                        [{"x":["compressive","parameter","debiasing","regression","precision","impressive","evidences","procedure","guarantees","numerical","iterative","theoretical","optimization","generalize","selection","guarantee","constrained","analogous","performance","convergence","thresholding","algorithm","solutions","underdetermined","estimation","according","assignments","efficient","accelerated","tractable","proposing","computationally","dimensions","integration","posterior","locations","difficult","inference","theoretically","nonparametric","attractive","accelerate","guaranteed","predictive","dimensional","generally","performed","especially","distribution","likelihood","usefulness","measuring","experimentally","gaussianity","unreliable","possesses","statistical","fundamental","estimator","practical","demonstrated","regularized","clustering","necessarily","objective","applications","estimating","demonstrate","dimension","influence","including","knowledge","strategies","different","prediction","multimodal","outperformed","information","approaches","combination","available","multilabel","architecture","modalities","representation","activation","intermediate","classification","evaluated","multiplicative","fingerprinting","framework","approximately","conventional","reference","conclusion","undersampling","reconstruction","quantified","agreement","simulated","equations","dictionary","estimated","dictionaries","measurements","tensorflow","synthesis","classifier","conditional","synthesizing","adversarial","conditioning","photorealistic","assessing","exhibiting","challenge","resolution","coherence","generative","auxiliary","assessment","diversity","construct","discriminability","employing","comparable","artificially","introduce","resources","considered","candidate","independent","environment","limitation","important","promising","benchmark","represent","congestion","decentralized","applicability","allocation","difference","satisfied","analysing","assumptions","literature","abstraction","omnipresent","behaviour","application","highlight","reinforcement","imitation","experimental","estimators","distillation","predictions","overfitting","transfers","baselines","parameters","optimized","effective","emergencies","algorithms","disasters","smartphones","excellent","everywhere","awareness","situations","researchers","situation","techniques","understanding","challenges","therefore","situational","decisions","consequently","installed","emergency","quadratic","approximation","multiplication","bernsteins","inequality","randomized","distributed","experiments","technique","architectures","probability","coordinate","clickstream","regularization","addresses","empirically","particular","modifications","generalized","algorithmic","parallelization","providing","principles","factorized","representations","autoencoder","properties","disentangled","variational","minimized","computation","enforcing","theoretic","injecting","automatically","structure","generalization","intuitions","efficiently","activations","challenging","incorporate","documents","probabilistic","nonconjugate","flexibility","currently","instances","correctly","extracted","proportion","accurately","nevertheless","investigates","classified","predicting","visibility","performing","navigation","management","autonomous","surveillance","determine","analytics","conditions","computational","utilizing","historically","intelligence","objectives","partially","simultaneous","amor ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	gaussianity
# 	clickstream
# 	nonconjugate
# 	amortization
# 	blockwise
# 	subtleties
# 	distributionally
# 	downweighting
# 	reversing
# 	rightarrow
# 	ancestral
# 	faithfully
# 	sociology
# 	suffering
# 	reparameterization
# 	reparameterizing
# 	transplantation
# 	precisions
# 	thetastar
# 	preconditioned
# Some words which never appear in Statistics papers:
# 	emergencies
# 	disasters
# 	situational
# 	installed
# 	historically
# 	complementarity
# 	publication
# 	vulnerabilities
# 	worldwide
# 	crowdsource
# 	happiness
# 	atmosphere
# 	imitating
# 	coalition
# 	manipulators
# 	imprecision
# 	reordering
# 	washington
# 	mechanistic
# 	conversational

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0426580660865334e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.75
